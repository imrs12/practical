# %% [markdown]
# <a href="https://colab.research.google.com/github/imrs12/practical/blob/main/7th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas plotly faker
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting faker
#   Downloading faker-40.15.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading faker-40.15.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.6 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.15.0

# %%
import pandas as pd
import random
import plotly.express as px
from faker import Faker

# %%
fake = Faker()

sentiments = ['Positive', 'Negative', 'Neutral']
hashtags = ['#AI', '#Tech', '#DataScience', '#Python', '#Startup']

data = []

for i in range(200) :
  post = {
      'user': fake.user_name(),
      'post_text': fake.sentence(),
      'sentiment': random.choice(sentiments),
      'likes': random.randint(10,500),
      'comments': random.randint(1,100),
      'shares': random.randint(1,50),
      'hashtag': random.choice(hashtags)
  }
  data.append(post)

df = pd.DataFrame(data)

df.head()
# Out:
#             user                                          post_text sentiment  \
# 0      mooredawn     Arm include evidence machine usually describe.   Neutral
# 1   frenchashley  Admit young century job cultural discover reme...   Neutral
# 2        david19               Beyond ahead example increase white.  Negative
# 3        frank03                    Person serve teacher story yet.  Negative
# 4  lorettahughes     Fund medical hear and growth history get baby.   Neutral
#
#    likes  comments  shares       hashtag
# 0    268        45       7      #Startup
# 1    479        43      43  #DataScience
# 2    214        97      17         #Tech
# 3    262        16      25       #Python
# 4    166        79      30         #Tech

# %%
df['engagement'] = df['likes'] + df['comments'] + df['shares']

df.head()
# Out:
#             user                                          post_text sentiment  \
# 0      mooredawn     Arm include evidence machine usually describe.   Neutral
# 1   frenchashley  Admit young century job cultural discover reme...   Neutral
# 2        david19               Beyond ahead example increase white.  Negative
# 3        frank03                    Person serve teacher story yet.  Negative
# 4  lorettahughes     Fund medical hear and growth history get baby.   Neutral
#
#    likes  comments  shares       hashtag  engagement
# 0    268        45       7      #Startup         320
# 1    479        43      43  #DataScience         565
# 2    214        97      17         #Tech         328
# 3    262        16      25       #Python         303
# 4    166        79      30         #Tech         275

# %%
sentiment_count = df['sentiment'].value_counts().reset_index()
sentiment_count.columns = ['Sentiment', 'Count']

fig = px.pie(
    sentiment_count,
    values='Count',
    names='Sentiment',
    title="Sentiment Distribution"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40e04092-862f-4c4b-bb6f-864a1a1232ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e04092-862f-4c4b-bb6f-864a1a1232ce")) {                    Plotly.newPlot(                        "40e04092-862f-4c4b-bb6f-864a1a1232ce",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sentiment=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Positive","Neutral","Negative"],"legendgroup":"","name":"","showlegend":true,"values":[75,68,57],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histog ...

# %%
hashtag_count = df['hashtag'].value_counts().reset_index()
hashtag_count.columns = ["Hashtag", "Count"]

fig = px.bar(
    hashtag_count,
    x= "Hashtag",
    y="Count",
    title="Trending Hashtags"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3aa3a82b-5d8c-42c5-89c0-2e1d6279494e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aa3a82b-5d8c-42c5-89c0-2e1d6279494e")) {                    Plotly.newPlot(                        "3aa3a82b-5d8c-42c5-89c0-2e1d6279494e",                        [{"alignmentgroup":"True","hovertemplate":"Hashtag=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["#DataScience","#Python","#Startup","#Tech","#AI"],"xaxis":"x","y":[42,42,41,41,34],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinew ...

# %%
fig = px.scatter(
    df,
    x="likes",
    y="shares",
    color="sentiment",
    size='engagement',
    title="Engagement Analysis"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="19765251-e804-4276-bf06-6980b726e53b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19765251-e804-4276-bf06-6980b726e53b")) {                    Plotly.newPlot(                        "19765251-e804-4276-bf06-6980b726e53b",                        [{"hovertemplate":"sentiment=Neutral\u003cbr\u003elikes=%{x}\u003cbr\u003eshares=%{y}\u003cbr\u003eengagement=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#636efa","size":[320,565,275,48,273,132,319,534,179,309,212,230,253,443,247,566,377,382,275,241,319,276,395,116,579,131,505,370,278,294,188,469,490,504,556,206,510,511,586,62,405,334,350,363,264,276,227,546,217,62,271,537,285,344,469,424,486,152,558,344,447,221,99,344,111,559,350,122],"sizemode":"area","sizeref":1.5775,"symbol":"circle"},"mode":"markers","name":"Neutral","orientation":"v","showlegend":true,"x":[268,479,166,31,228,120,288,481,116,219,155,157,200,377,170,442,346,299,183,181,213,224,305,84,453,81,420,323,162,285,105,360,379,428,484,181,451,434,460,11,315,226,284,249,213,247,136,484,190,53,215,409,214,317,354,373,378,95,499,235,396,174,54,294,57,426,247,44],"xaxis":"x","y":[7,43,30,6,31,4,13,25,42,33,35,9,41,17,21,24,4,38,26,43,13,37,16,19,47,25,31,4,49,4,16,29,38,39,25,15,33,10,31,30,14,27,8,34,17,2,7,26,2,8,9,37,19,1,39,48,47,46,40,47,34,23,16,12,3,36,46,14],"yaxis":"y","type":"scatter"},{"hovertemplate":"sentiment=Negative\u003cbr\u003elikes=%{x}\u003cbr\u003eshares=%{y}\u003cbr\u003eengagement=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#EF553B","size":[328,303,317,535,194,455,142,335,210,495,418,241,497,307,63,350,178,503,336,329,180,327,190,554,363,588,473,477,379,204,549,515,542,219,74,180,78,180,274,103,409,151,231,249,491,221,163,290,228,202,463,315,184,631,472,283,270],"sizemode":"area","sizeref":1.5775,"symbol":"circle"},"mode":"markers","name":"Negative","orientation":"v","showlegend":true,"x":[214,262,276,481,160,347,98,214,162,455,374,191,403,256,42,204,65,403,315,265,70,256,102,455,280,494,396,418,344,140,471,403,435,138,19,65,19,45,239,68,304,128,172,157,380,171,121,246,187,116,357,219,118,496,343,189,194],"xaxis":"x","y":[17,25,6,14,3,50,41,40,27,20,28,48,44,4,1,49,28,2,13,12,23,38,18,50,39,40,24,25,6,37,31,46,40,49,23,50,44,42,18,31,37,21,50,16,32,6,13,7,17,24,9,49,4,35,29,6,3],"yaxis":"y","type":"scatter"},{"hovertemplate":"sentiment=Positive\u003cbr\u003elikes=%{x}\u003cbr\u003eshares=%{y}\u003cbr\u003eengagement=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#00cc96","size":[135,78,494,357,621,533,506,359,462,322,447,361,128,67,406,193,581,266,108,227,328,344,112,474,185,197,161,454,478,162,271,299,504,241,143,494,331,582,356,565,595,512,295,466,477,566,78,535,512,294,139,579,421,452,489,481,263,547,129,503,231,288,592,483,521,490,617,260,400,296,443,262,474,194,350],"sizemode":"area","sizeref":1.5775,"symbol":"circle"},"mode":"markers","name":"Positive","orientation":"v","showlegend":true,"x":[106,49,360,237,493,462,466,270,436,257,424,309,45,19,294,140,488,138,35,219,195,312,20,412,138,84,37,345,393,44,160,213,448,122,97,409,283,491,320,487,458,461,194,433,377,464,25,412,463,283,17,492,358,430,421,423,177,469,50,410,149,199,485,444,448,440,480,181,331,183,365,162,436,150,259],"xaxis":"x","y":[26,5,34,49,46,44,1,23,21,8,12,24,32,45,24,22,44,50,27,3,39,26,40,14,8,40,34,35,40,37,35,6,40,49,35,6,7,50,20,16,41,40,38,19,8,24,34,45,35,2,38,40,19,7,45,2,29,15,46,3,5,32,32,33,12,11,44,10,11,47,12,34,18,31,38],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","c ...

# %%
top_posts = df.sort_values(by="engagement", ascending=False).head(10)

top_posts[["user", "post_text", "engagement"]]
# Out:
#                user                                          post_text  \
# 188         otaylor              Seek right the station young reality.
# 33      melissaboyd      Describe without democratic put appear ready.
# 177       cfranklin               Century color newspaper admit floor.
# 125        shelly48  Reveal sit industry major himself statement bl...
# 171         wberger    Activity themselves theory kid test food class.
# 65          scott69                  By detail radio reality law turn.
# 109  bethanysanchez                   Operation record each must fact.
# 120         amber17  Issue fish company animal professor central rise.
# 74   nicolemartinez          Hear possible tax take instead she whose.
# 147      benjamin26                        Sea cost card article make.
#
#      engagement
# 188         631
# 33          621
# 177         617
# 125         595
# 171         592
# 65          588
# 109         586
# 120         582
# 74          581
# 147         579

# %%
report = {
    "Total Posts": len(df),
    "Average Likes": df["likes"].mean(),
    "Average comments": df['comments'].mean(),
    "Average  Shares": df['shares'].mean(),
    "Most Trending Hashtag": df['hashtag'].mode()[0]
}

report
# Out:
# {'Total Posts': 200,
#  'Average Likes': np.float64(268.275),
#  'Average comments': np.float64(48.275),
#  'Average  Shares': np.float64(25.93),
#  'Most Trending Hashtag': '#DataScience'}
